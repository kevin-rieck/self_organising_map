# %%
import numpy as np
from objects import SOM, get_watershed
import matplotlib.pyplot as plt

# %%
np.random.seed(42)
colors = np.random.rand(30, 3)

# %%
som = SOM(30, 30, dim=3, n_iterations=3000, alpha=0.3, metric='euclidean')

# %%
som.fit(colors)
# Out:
# EPOCH: 0 --- TIME 0.062s
# EPOCH: 1 --- TIME 0.047s
# EPOCH: 2 --- TIME 0.031s
# EPOCH: 3 --- TIME 0.016s
# EPOCH: 4 --- TIME 0.016s
# EPOCH: 5 --- TIME 0.031s
# EPOCH: 6 --- TIME 0.016s
# EPOCH: 7 --- TIME 0.016s
# EPOCH: 8 --- TIME 0.031s
# EPOCH: 9 --- TIME 0.047s
# EPOCH: 10 --- TIME 0.016s
# EPOCH: 11 --- TIME 0.031s
# EPOCH: 12 --- TIME 0.016s
# EPOCH: 13 --- TIME 0.016s
# EPOCH: 14 --- TIME 0.016s
# EPOCH: 15 --- TIME 0.047s
# EPOCH: 16 --- TIME 0.016s
# EPOCH: 17 --- TIME 0.047s
# EPOCH: 18 --- TIME 0.031s
# EPOCH: 19 --- TIME 0.016s
# EPOCH: 20 --- TIME 0.031s
# EPOCH: 21 --- TIME 0.031s
# EPOCH: 22 --- TIME 0.016s
# EPOCH: 23 --- TIME 0.017s
# EPOCH: 24 --- TIME 0.031s
# EPOCH: 25 --- TIME 0.031s
# EPOCH: 26 --- TIME 0.016s
# EPOCH: 27 --- TIME 0.037s
# EPOCH: 28 --- TIME 0.016s
# EPOCH: 29 --- TIME 0.016s
# EPOCH: 30 --- TIME 0.016s
# EPOCH: 31 --- TIME 0.031s
# EPOCH: 32 --- TIME 0.016s
# EPOCH: 33 --- TIME 0.016s
# EPOCH: 34 --- TIME 0.047s
# EPOCH: 35 --- TIME 0.031s
# ...

# %%
# %matplotlib qt
plt.imshow(som._get_clusters(15, clustering_method='kmeans'), cmap='plasma')
plt.savefig(r'C:\Users\Apex\Desktop\MA\graphics\cluster_kmeans.png', dpi=600)
