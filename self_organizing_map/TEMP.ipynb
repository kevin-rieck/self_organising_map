# %%
import numpy as np
from self_organizing_map.objects import SOM, get_watershed
import matplotlib.pyplot as plt

# %%
np.random.seed(42)
colors = np.random.rand(30, 3)

# %%
som = SOM(50, 100, dim=3, n_iterations=1000, alpha=0.3, metric='euclidean')

# %%
som.fit(colors)
# Out:
# EPOCH: 0 --- TIME 0.094s
# EPOCH: 1 --- TIME 0.078s
# EPOCH: 2 --- TIME 0.062s
# EPOCH: 3 --- TIME 0.062s
# EPOCH: 4 --- TIME 0.078s
# EPOCH: 5 --- TIME 0.078s
# EPOCH: 6 --- TIME 0.062s
# EPOCH: 7 --- TIME 0.080s
# EPOCH: 8 --- TIME 0.062s
# EPOCH: 9 --- TIME 0.078s
# EPOCH: 10 --- TIME 0.062s
# EPOCH: 11 --- TIME 0.080s
# EPOCH: 12 --- TIME 0.063s
# EPOCH: 13 --- TIME 0.078s
# EPOCH: 14 --- TIME 0.062s
# EPOCH: 15 --- TIME 0.078s
# EPOCH: 16 --- TIME 0.077s
# EPOCH: 17 --- TIME 0.078s
# EPOCH: 18 --- TIME 0.078s
# EPOCH: 19 --- TIME 0.078s
# EPOCH: 20 --- TIME 0.062s
# EPOCH: 21 --- TIME 0.078s
# EPOCH: 22 --- TIME 0.078s
# EPOCH: 23 --- TIME 0.078s
# EPOCH: 24 --- TIME 0.063s
# EPOCH: 25 --- TIME 0.081s
# EPOCH: 26 --- TIME 0.063s
# EPOCH: 27 --- TIME 0.078s
# EPOCH: 28 --- TIME 0.063s
# EPOCH: 29 --- TIME 0.078s
# EPOCH: 30 --- TIME 0.078s
# EPOCH: 31 --- TIME 0.079s
# EPOCH: 32 --- TIME 0.062s
# EPOCH: 33 --- TIME 0.078s
# EPOCH: 34 --- TIME 0.063s
# EPOCH: 35 --- TIME 0.062s
# EPOCH: 36 --- TIME 0.078s
# EPOCH: 37 --- TIME 0.078s
# EPOCH: 38 --- TIME 0.073s
# EPOCH: 39 --- TIME 0.066s
# EPOCH: 40 --- TIME 0.062s
# EPOCH: 41 --- TIME 0.078s
# EPOCH: 42 --- TIME 0.062s
# EPOCH: 43 --- TIME 0.078s
# EPOCH: 44 --- TIME 0.063s
# EPOCH: 45 --- TIME 0.078s
# EPOCH: 46 --- TIME 0.062s
# EPOCH: 47 --- TIME 0.078s
# EPOCH: 48 --- TIME 0.062s
# EPOCH: 49 --- TIME 0.078s
# EPOCH: 50 --- TIME 0.063s
# EPOCH: 51 --- TIME 0.062s
# EPOCH: 52 --- TIME 0.078s
# EPOCH: 53 --- TIME 0.064s
# EPOCH: 54 --- TIME 0.078s
# EPOCH: 55 --- TIME 0.062s
# EPOCH: 56 --- TIME 0.078s
# EPOCH: 57 --- TIME 0.078s
# EPOCH: 58 --- TIME 0.062s
# EPOCH: 59 --- TIME 0.078s
# EPOCH: 60 --- TIME 0.078s
# EPOCH: 61 --- TIME 0.073s
# EPOCH: 62 --- TIME 0.081s
# EPOCH: 63 --- TIME 0.094s
# EPOCH: 64 --- TIME 0.078s
# EPOCH: 65 --- TIME 0.062s
# EPOCH: 934 --- TIME 0.094s
# EPOCH: 935 --- TIME 0.094s
# EPOCH: 936 --- TIME 0.094s
# EPOCH: 937 --- TIME 0.094s
# EPOCH: 938 --- TIME 0.078s
# EPOCH: 939 --- TIME 0.094s
# EPOCH: 940 --- TIME 0.095s
# EPOCH: 941 --- TIME 0.075s
# EPOCH: 942 --- TIME 0.109s
# EPOCH: 943 --- TIME 0.078s
# EPOCH: 944 --- TIME 0.094s
# EPOCH: 945 --- TIME 0.109s
# EPOCH: 946 --- TIME 0.094s
# EPOCH: 947 --- TIME 0.094s
# EPOCH: 948 --- TIME 0.095s
# EPOCH: 949 --- TIME 0.094s
# EPOCH: 950 --- TIME 0.078s
# EPOCH: 951 --- TIME 0.096s
# EPOCH: 952 --- TIME 0.109s
# EPOCH: 953 --- TIME 0.109s
# EPOCH: 954 --- TIME 0.094s
# EPOCH: 955 --- TIME 0.094s
# EPOCH: 956 --- TIME 0.094s
# EPOCH: 957 --- TIME 0.094s
# EPOCH: 958 --- TIME 0.078s
# EPOCH: 959 --- TIME 0.109s
# EPOCH: 960 --- TIME 0.078s
# EPOCH: 961 --- TIME 0.094s
# EPOCH: 962 --- TIME 0.082s
# EPOCH: 963 --- TIME 0.094s
# EPOCH: 964 --- TIME 0.094s
# EPOCH: 965 --- TIME 0.094s
# EPOCH: 966 --- TIME 0.094s
# EPOCH: 967 --- TIME 0.079s
# EPOCH: 968 --- TIME 0.094s
# EPOCH: 969 --- TIME 0.109s
# EPOCH: 970 --- TIME 0.078s
# EPOCH: 971 --- TIME 0.094s
# EPOCH: 972 --- TIME 0.094s
# EPOCH: 973 --- TIME 0.080s
# EPOCH: 974 --- TIME 0.094s
# EPOCH: 975 --- TIME 0.094s
# EPOCH: 976 --- TIME 0.078s
# EPOCH: 977 --- TIME 0.094s
# EPOCH: 978 --- TIME 0.094s
# EPOCH: 979 --- TIME 0.078s
# EPOCH: 980 --- TIME 0.094s
# EPOCH: 981 --- TIME 0.094s
# EPOCH: 982 --- TIME 0.078s
# EPOCH: 983 --- TIME 0.094s
# EPOCH: 984 --- TIME 0.080s
# EPOCH: 985 --- TIME 0.094s
# EPOCH: 986 --- TIME 0.094s
# EPOCH: 987 --- TIME 0.094s
# EPOCH: 988 --- TIME 0.109s
# EPOCH: 989 --- TIME 0.109s
# EPOCH: 990 --- TIME 0.109s
# EPOCH: 991 --- TIME 0.109s
# EPOCH: 992 --- TIME 0.125s
# EPOCH: 993 --- TIME 0.109s
# EPOCH: 994 --- TIME 0.190s
# EPOCH: 995 --- TIME 0.141s
# EPOCH: 996 --- TIME 0.109s
# EPOCH: 997 --- TIME 0.125s
# EPOCH: 998 --- TIME 0.125s
# EPOCH: 999 --- TIME 0.111s
# Saving figure in C:\Users\Apex\PycharmProjects\self_organizing_map\self_organizing_map\images

# %% [markdown]
# # Dendrogram

# %%
from scipy.cluster import hierarchy

# %%
m_vects = som.get_centroids()
m_vects = np.array(m_vects).reshape(-1, 3)
m_vects.shape
# Out:
# (25, 3)

# %%
Z = hierarchy.linkage(m_vects, 'average')
# %matplotlib qt
plt.style.use('seaborn-poster')
fig, ax = plt.subplots(1, 1, figsize=(11.69, 6))

dn = hierarchy.dendrogram(Z, ax=ax, color_threshold=0)
ax.set_title('Dendrogram')
ax.set_xlabel('Model vector ID')
ax.set_ylabel('Euclidean distance')

ax.xaxis.label.set_fontsize(18)
ax.yaxis.label.set_fontsize(18)
ax.title.set_fontsize(18)
fig.tight_layout()

# %%
# %matplotlib qt
plt.style.use('seaborn-poster')
fig, ax = plt.subplots(1, 1, figsize=(11.69, 5))
cmp = ax.imshow(som.cluster, cmap='plasma')
#ax.set_title('Unified distance matrix')
ax.set_xlabel('Column index of neuron')
ax.set_ylabel('Row index of neuron')
ax.xaxis.tick_top()
ax.xaxis.set_label_position('top') 
cbar = plt.colorbar(cmp, orientation='vertical', fraction=0.04)
cbar.set_label('Distance rel. to max')
fig.tight_layout()

#fig.savefig(r'C:\Users\Apex\Desktop\MA\graphics\u_matrix_representation.png', dpi=600)

# %%
u_array = som.get_umatrix()

# %%
x = np.linspace(0, 50, 50)
y = np.linspace(0, 100, 100)

X, Y = np.meshgrid(y, x)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
plt.style.use('seaborn-poster')

fig = plt.figure(figsize=(11.69, 7))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, u_array, cmap='Greys')
ax.set_xlabel('Column index of neuron')
ax.set_ylabel('Row index of neuron')
ax.set_zlabel('Distance rel. to max')

ax.xaxis.labelpad=30
ax.yaxis.labelpad=30
ax.zaxis.labelpad=20

#fig.tight_layout()
ax.view_init(45, -135)

# %%
# %matplotlib qt
plt.style.use('seaborn-poster')

discrete_matshow(som._get_clusters(13, 'agg'))
# plt.savefig(r'C:\Users\Apex\Desktop\MA\graphics\cluster_watershed_13clusters.png', dpi=600)
# Out:
# Saving figure in C:\Users\Apex\PycharmProjects\self_organizing_map\self_organizing_map\images

# %%
def discrete_matshow(data):
    fig, ax = plt.subplots(1, 1, figsize=(11.69, 11.69/2))
    #get discrete colormap
    cmap = plt.get_cmap('inferno', np.max(data)-np.min(data)+1)
    # set limits .5 outside true range
    mat = ax.matshow(data,cmap=cmap,vmin = np.min(data)-.5, vmax = np.max(data)+.5)
    #tell the colorbar to tick at integers
    ax.set_xlabel('Column index of neuron')
    ax.set_ylabel('Row index of neuron')
    ax.xaxis.tick_top()
    ax.xaxis.set_label_position('top') 
    cax = plt.colorbar(mat, ticks=np.arange(np.min(data),np.max(data)+1), fraction=0.03, orientation='vertical')
    cax.set_label('Cluster number')
    fig.tight_layout()

# %%
from self_organizing_map.objects import Splitter
import os
import pandas as pd
# Out:
# Package with submodules:
# - objects contains various objects for process monitoring application
# - utility_funcs contains additional helper functions
# - Jupyter notebooks that explain usage of the objects
# C:\Users\Apex\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
folder = r'D:\MA_data\SensorII_28082018-03092018\shop_floor_test'
destination_folder = r'D:\MA_data\SensorII_28082018-03092018\splitted'

splitter = Splitter()

# %%
for i in range(97):
    db_name = r'shop_floor_test{}.db'.format(i)
    db_path = os.path.join(folder, db_name)
    splitter.split(3e6, destination_folder, db_path)
# Out:
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 0 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample0.csv
# Sample 1 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample1.csv
# Sample 2 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample2.csv
# Sample 3 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample3.csv
# Sample 4 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample4.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 5 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample5.csv
# Sample 6 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample6.csv
# Sample 7 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample7.csv
# Sample 8 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample8.csv
# Sample 9 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample9.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 10 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample10.csv
# Sample 11 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample11.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 12 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample12.csv
# Sample 13 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample13.csv
# Sample 14 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample14.csv
# Sample 15 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample15.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 16 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample16.csv
# Sample 17 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample17.csv
# Sample 18 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample18.csv
# Sample 19 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample19.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 20 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample20.csv
# Sample 21 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample21.csv
# Sample 22 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample22.csv
# Sample 23 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample23.csv
# Sample 24 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample24.csv
# Sample 25 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample25.csv
# Sample 26 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample26.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 27 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample27.csv
# Sample 28 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample28.csv
# Sample 29 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample29.csv
# Sample 30 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample30.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 31 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample31.csv
# Sample 32 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample32.csv
# Sample 33 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample33.csv
# Sample 34 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample34.csv
# Sample 35 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample35.csv
# Sample 36 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample36.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 37 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample37.csv
# Sample 38 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample38.csv
# Sample 39 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample39.csv
# Sample 40 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample40.csv
# Sample 41 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample41.csv
# Sample 42 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample42.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 43 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample43.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 44 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample44.csv
# Sample 45 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample45.csv
# Sample 46 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample46.csv
# Sample 47 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample47.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 48 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample48.csv
# Sample 49 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample49.csv
# Sample 50 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample50.csv
# Sample 51 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample51.csv
# Sample 52 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample52.csv
# Sample 53 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample53.csv
# Sample 54 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample54.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 55 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample55.csv
# Sample 56 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample56.csv
# Sample 57 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample57.csv
# Sample 58 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample58.csv
# Sample 59 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample59.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 60 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample60.csv
# Sample 61 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample61.csv
# Sample 62 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample62.csv
# Sample 63 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample63.csv
# Sample 64 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample64.csv
# Sample 65 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample65.csv
# Sample 66 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample66.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 67 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample67.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 68 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample68.csv
# Sample 69 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample69.csv
# Sample 70 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample70.csv
# Sample 71 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample71.csv
# Sample 72 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample72.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 73 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample73.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 74 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample74.csv
# Sample 75 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample75.csv
# Sample 76 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample76.csv
# Sample 77 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample77.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 78 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample78.csv
# Sample 79 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample79.csv
# Sample 80 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample80.csv
# Sample 81 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample81.csv
# Sample 82 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample82.csv
# Sample 83 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample83.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 84 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample84.csv
# Sample 85 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample85.csv
# Sample 86 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample86.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 87 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample87.csv
# Sample 88 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample88.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 89 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample89.csv
# Sample 90 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample90.csv
# Sample 91 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample91.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 92 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample92.csv
# Sample 93 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample93.csv
# Sample 94 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample94.csv
# Sample 95 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample95.csv
# Sample 96 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample96.csv
# Sample 97 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample97.csv
# Sample 98 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample98.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 99 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample99.csv
# Sample 100 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample100.csv
# Sample 101 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample101.csv
# Sample 102 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample102.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 103 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample103.csv
# Sample 104 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample104.csv
# Sample 105 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample105.csv
# Sample 106 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample106.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 107 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample107.csv
# Sample 108 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample108.csv
# Sample 109 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample109.csv
# Sample 110 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample110.csv
# Sample 111 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample111.csv
# Sample 112 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample112.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 113 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample113.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 114 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample114.csv
# Sample 115 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample115.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 116 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample116.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 117 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample117.csv
# Sample 118 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample118.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 119 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample119.csv
# Sample 120 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample120.csv
# Sample 121 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample121.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 122 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample122.csv
# Sample 123 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample123.csv
# Sample 124 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample124.csv
# Sample 125 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample125.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 126 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample126.csv
# Sample 127 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample127.csv
# Sample 128 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample128.csv
# Sample 129 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample129.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 130 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample130.csv
# Sample 131 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample131.csv
# Sample 132 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample132.csv
# Sample 133 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample133.csv
# Sample 134 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample134.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 135 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample135.csv
# Sample 136 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample136.csv
# Sample 137 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample137.csv
# Sample 138 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample138.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 139 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample139.csv
# Sample 140 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample140.csv
# Sample 141 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample141.csv
# Sample 142 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample142.csv
# Sample 143 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample143.csv
# Sample 144 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample144.csv
# Sample 145 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample145.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 146 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample146.csv
# Sample 147 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample147.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 148 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample148.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 149 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample149.csv
# Sample 150 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample150.csv
# Sample 151 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample151.csv
# Sample 152 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample152.csv
# Sample 153 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample153.csv
# Sample 154 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample154.csv
# Sample 155 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample155.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 156 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample156.csv
# Sample 157 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample157.csv
# Sample 158 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample158.csv
# Sample 159 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample159.csv
# Sample 160 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample160.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 161 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample161.csv
# Sample 162 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample162.csv
# Sample 163 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample163.csv
# Sample 164 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample164.csv
# Sample 165 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample165.csv
# Sample 166 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample166.csv
# Sample 167 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample167.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 168 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample168.csv
# Sample 169 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample169.csv
# Sample 170 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample170.csv
# Sample 171 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample171.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 172 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample172.csv
# Sample 173 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample173.csv
# Sample 174 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample174.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 175 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample175.csv
# Sample 176 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample176.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 177 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample177.csv
# Sample 178 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample178.csv
# Sample 179 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample179.csv
# Sample 180 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample180.csv
# Sample 181 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample181.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 182 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample182.csv
# Sample 183 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample183.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 184 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample184.csv
# Sample 185 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample185.csv
# Sample 186 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample186.csv
# Sample 187 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample187.csv
# Sample 188 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample188.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 189 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample189.csv
# Sample 190 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample190.csv
# Sample 191 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample191.csv
# Sample 192 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample192.csv
# Sample 193 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample193.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 194 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample194.csv
# Sample 195 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample195.csv
# Sample 196 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample196.csv
# Sample 197 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample197.csv
# Sample 198 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample198.csv
# Sample 199 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample199.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 200 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample200.csv
# Sample 201 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample201.csv
# Sample 202 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample202.csv
# Sample 203 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample203.csv
# Sample 204 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample204.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 205 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample205.csv
# Sample 206 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample206.csv
# Sample 207 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample207.csv
# Sample 208 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample208.csv
# Sample 209 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample209.csv
# Sample 210 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample210.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 211 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample211.csv
# Sample 212 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample212.csv
# Sample 213 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample213.csv
# Sample 214 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample214.csv
# Sample 215 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample215.csv
# Sample 216 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample216.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 217 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample217.csv
# Sample 218 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample218.csv
# Sample 219 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample219.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 220 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample220.csv
# Sample 221 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample221.csv
# Sample 222 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample222.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 223 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample223.csv
# Sample 224 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample224.csv
# Sample 225 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample225.csv
# Sample 226 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample226.csv
# Sample 227 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample227.csv
# Sample 228 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample228.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 229 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample229.csv
# Sample 230 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample230.csv
# Sample 231 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample231.csv
# Sample 232 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample232.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 233 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample233.csv
# Sample 234 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample234.csv
# Sample 235 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample235.csv
# Sample 236 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample236.csv
# Sample 237 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample237.csv
# Sample 238 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample238.csv
# Sample 239 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample239.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 240 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample240.csv
# Sample 241 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample241.csv
# Sample 242 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample242.csv
# Sample 243 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample243.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 244 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample244.csv
# Sample 245 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample245.csv
# Sample 246 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample246.csv
# Sample 247 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample247.csv
# Sample 248 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample248.csv
# Sample 249 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample249.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 250 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample250.csv
# Sample 251 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample251.csv
# Sample 252 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample252.csv
# Sample 253 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample253.csv
# Sample 254 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample254.csv
# Sample 255 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample255.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 256 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample256.csv
# Sample 257 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample257.csv
# Sample 258 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample258.csv
# Sample 259 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample259.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 260 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample260.csv
# Sample 261 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample261.csv
# Sample 262 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample262.csv
# Sample 263 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample263.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 264 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample264.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 265 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample265.csv
# Sample 266 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample266.csv
# Sample 267 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample267.csv
# Sample 268 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample268.csv
# Sample 269 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample269.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 270 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample270.csv
# Sample 271 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample271.csv
# Sample 272 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample272.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 273 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample273.csv
# Sample 274 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample274.csv
# Sample 275 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample275.csv
# Sample 276 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample276.csv
# Sample 277 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample277.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 278 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample278.csv
# Sample 279 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample279.csv
# Sample 280 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample280.csv
# Sample 281 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample281.csv
# Sample 282 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample282.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 283 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample283.csv
# Sample 284 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample284.csv
# Sample 285 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample285.csv
# Sample 286 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample286.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 287 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample287.csv
# Sample 288 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample288.csv
# Sample 289 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample289.csv
# Sample 290 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample290.csv
# Sample 291 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample291.csv
# Sample 292 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample292.csv
# Sample 293 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample293.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 294 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample294.csv
# Sample 295 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample295.csv
# Sample 296 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample296.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 297 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample297.csv
# Sample 298 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample298.csv
# Sample 299 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample299.csv
# Sample 300 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample300.csv
# Sample 301 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample301.csv
# Sample 302 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample302.csv
# Sample 303 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample303.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 304 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample304.csv
# Sample 305 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample305.csv
# Sample 306 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample306.csv
# Sample 307 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample307.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 308 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample308.csv
# Sample 309 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample309.csv
# Sample 310 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample310.csv
# Sample 311 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample311.csv
# Sample 312 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample312.csv
# Sample 313 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample313.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 314 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample314.csv
# Sample 315 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample315.csv
# Sample 316 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample316.csv
# Sample 317 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample317.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 318 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample318.csv
# Sample 319 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample319.csv
# Sample 320 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample320.csv
# Sample 321 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample321.csv
# Sample 322 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample322.csv
# Sample 323 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample323.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 324 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample324.csv
# Sample 325 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample325.csv
# Sample 326 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample326.csv
# Sample 327 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample327.csv
# Sample 328 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample328.csv
# Sample 329 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample329.csv
# Sample 330 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample330.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# ...
# Sample 712 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample712.csv
# Sample 713 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample713.csv
# Sample 714 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample714.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 715 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample715.csv
# Sample 716 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample716.csv
# Sample 717 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample717.csv
# Sample 718 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample718.csv
# Sample 719 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample719.csv
# Sample 720 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample720.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 721 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample721.csv
# Sample 722 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample722.csv
# Sample 723 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample723.csv
# Sample 724 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample724.csv
# Sample 725 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample725.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 726 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample726.csv
# Sample 727 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample727.csv
# Sample 728 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample728.csv
# Sample 729 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample729.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 730 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample730.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 731 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample731.csv
# Sample 732 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample732.csv
# Sample 733 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample733.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 734 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample734.csv
# Sample 735 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample735.csv
# Sample 736 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample736.csv
# Sample 737 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample737.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 738 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample738.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 739 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample739.csv
# Sample 740 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample740.csv
# Sample 741 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample741.csv
# Sample 742 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample742.csv
# Sample 743 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample743.csv
# Sample 744 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample744.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 745 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample745.csv
# Sample 746 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample746.csv
# Sample 747 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample747.csv
# Sample 748 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample748.csv
# Sample 749 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample749.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 750 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample750.csv
# Sample 751 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample751.csv
# Sample 752 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample752.csv
# Sample 753 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample753.csv
# Sample 754 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample754.csv
# Sample 755 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample755.csv
# Sample 756 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample756.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 757 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample757.csv
# Sample 758 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample758.csv
# Sample 759 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample759.csv
# Sample 760 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample760.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 761 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample761.csv
# Sample 762 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample762.csv
# Sample 763 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample763.csv
# Sample 764 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample764.csv
# Sample 765 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample765.csv
# Sample 766 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample766.csv
# Sample 767 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample767.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 768 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample768.csv
# Sample 769 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample769.csv
# Sample 770 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample770.csv
# Sample 771 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample771.csv
# Sample 772 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample772.csv
# Sample 773 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample773.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 774 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample774.csv
# Sample 775 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample775.csv
# Sample 776 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample776.csv
# Sample 777 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample777.csv
# Sample 778 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample778.csv
# Sample 779 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample779.csv
# Sample 780 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample780.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 781 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample781.csv
# Sample 782 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample782.csv
# Sample 783 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample783.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 784 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample784.csv
# Sample 785 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample785.csv
# Sample 786 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample786.csv
# Sample 787 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample787.csv
# Sample 788 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample788.csv
# Sample 789 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample789.csv
# Sample 790 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample790.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 791 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample791.csv
# Sample 792 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample792.csv
# Sample 793 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample793.csv
# Sample 794 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample794.csv
# Sample 795 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample795.csv
# Sample 796 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample796.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 797 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample797.csv
# Sample 798 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample798.csv
# Sample 799 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample799.csv
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Standstill detected. Marker appended.
# Sample 800 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample800.csv
# Sample 801 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample801.csv
# Sample 802 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample802.csv
# Sample 803 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample803.csv
# Sample 804 saved in D:\MA_data\SensorII_28082018-03092018\splitted\sample804.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-02477cc18a98> in <module>()
#       3     db_name = r'shop_floor_test{}.db'.format(i)
#       4     db_path = os.path.join(folder, db_name)
# ----> 5     splitter.split(3e6, destination_folder, db_path)
#
# c:\users\apex\pycharmprojects\self_organizing_map\self_organizing_map\objects.py in split(self, chunksize, destination_folder, db_path)
#    1348     def split(self, chunksize, destination_folder, db_path):
#    1349         self._read_in_chunks(chunksize, db_path)
# -> 1350         return self._find_standstill(destination_folder)
#    1351
#    1352     def _read_in_chunks(self, chunksize, db_path):
#
# c:\users\apex\pycharmprojects\self_organizing_map\self_organizing_map\objects.py in _find_standstill(self, destination_folder, seconds, axis, threshold)
#    1401                             os.makedirs(destination_folder)
#    1402
# -> 1403                         sample.to_csv(path_to_save)
#    1404                         print('Sample {} saved in {}'.format(self.sample_counter, path_to_save))
#    1405                         self.sample_counter += 1
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1522                                      doublequote=doublequote,
#    1523                                      escapechar=escapechar, decimal=decimal)
# -> 1524         formatter.save()
#    1525
#    1526         if path_or_buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in save(self)
#    1650                 self.writer = UnicodeWriter(f, **writer_kwargs)
#    1651
# -> 1652             self._save()
#    1653
#    1654         finally:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in _save(self)
#    1752                 break
#    1753
# -> 1754             self._save_chunk(start_i, end_i)
#    1755
#    1756     def _save_chunk(self, start_i, end_i):
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in _save_chunk(self, start_i, end_i)
#    1776                                         decimal=self.decimal,
#    1777                                         date_format=self.date_format,
# -> 1778                                         quoting=self.quoting)
#    1779
#    1780         lib.write_csv_rows(self.data, ix, self.nlevels, self.cols, self.writer)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in to_native_types(self, slicer, **kwargs)
#    2006         if slicer is not None:
#    2007             values = values[slicer]
# -> 2008         return values._format_native_types(**kwargs)
#    2009
#    2010     def _format_native_types(self, na_rep='', quoting=None, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in _format_native_types(self, na_rep, quoting, **kwargs)
#    2016             values = np.array(self, dtype=object, copy=True)
#    2017
# -> 2018         values[mask] = na_rep
#    2019         return values
#    2020
#
# KeyboardInterrupt:

# %%
    def _get_db_names(folder_path):
        paths = []

        entries = os.scandir(folder_path)

        for entry in entries:
            if entry.is_file() and entry.name[-3:] == '.db':
                db_path = os.path.join(folder_path, entry.name)
                paths.append(db_path)

            elif entry.is_dir():
                new_path = os.path.join(folder_path, entry.name)
                new_entries = os.scandir(new_path)

                for new_entry in new_entries:
                    if new_entry.name[-3:] == '.db':
                        db_path = os.path.join(new_path, new_entry.name)
                        paths.append(db_path)

        return paths

# %%
# %matplotlib qt
for i in range(20):
    number = 
    file_path=r'D:\MA_data\SensorII_28082018-03092018\splitted\sample{}.csv'.format(i)
    df = pd.read_csv(file_path)
    fig, ax = plt.subplots(1, 1)
    ax.plot(df['y'])

# %%
from self_organizing_map.utility_funcs import get_watershed

# %%
import matplotlib.pyplot as plt
from random import

# %%
img = plt.imread(r'C:\Users\Apex\PycharmProjects\self_organizing_map\self_organizing_map\images\')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-32dec6451f30> in <module>()
# ----> 1 img = plt.imread('.\\images\\10x10 som_SOM_epochs_100_metric_Cosine.jpg')
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in imread(*args, **kwargs)
#    2252 @docstring.copy_dedent(_imread)
#    2253 def imread(*args, **kwargs):
# -> 2254     return _imread(*args, **kwargs)
#    2255
#    2256
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in imread(fname, format)
#    1300
#    1301     if ext not in handlers:
# -> 1302         im = pilread(fname)
#    1303         if im is None:
#    1304             raise ValueError('Only know how to handle extensions: %s; '
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in pilread(fname)
#    1278         except ImportError:
#    1279             return None
# -> 1280         with Image.open(fname) as image:
#    1281             return pil_to_array(image)
#    1282
#
# ~\Anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2541
#    2542     if filename:
# -> 2543         fp = builtins.open(filename, "rb")
#    2544         exclusive_fp = True
#    2545
#
# FileNotFoundError: [Errno 2] No such file or directory: '.\\images\\10x10 som_SOM_epochs_100_metric_Cosine.jpg'
